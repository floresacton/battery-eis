# %%
import numpy as np

# %%
Vi = 10
r1 = 1
r2 = 1
c = 1

P = 9
Q = 0

h = .1
for i in range(100):

    Vo = (Vi - Q/c + np.sqrt((Q/c - Vi)**2 - 4*P*r1)) / 2

    Ic = Vi/r1 + (Q/c + Vo)*(-1/r1 - 1/r2) + r1/r2 * P / (Vi - (Q/c + Vo))

    Q += Ic * h
    print(Vo)
# Out:
# 9.0
# 8.887321424522007
# 8.784160725662561
# 8.68969187540005
# 8.603163847661493
# 8.52389333864238
# 8.451258253185639
# 8.384691870645932
# 8.323677613715903
# 8.26774435264446
# 8.216462185225371
# 8.16943863996887
# 8.126315256078634
# 8.086764499326074
# 8.050486977723654
# 8.017208925122489
# 7.986679924565465
# 7.958670846476595
# 7.932971979616494
# 7.90939133523197
# 7.887753107019267
# 7.867896271444025
# 7.849673314651234
# 7.832949073685041
# 7.817599681047339
# 7.803511602778855
# 7.7905807612661775
# 7.7787117348804165
# 7.767817027352701
# 7.757816400501424
# 7.748636264557186
# 7.740209120893411
# 7.732473052472216
# 7.725371257763161
# 7.718851624293834
# 7.712866338350853
# 7.7073715276729
# 7.702326934267846
# 7.697695614747612
# 7.693443665810197
# 7.689539972711328
# 7.685955978760633
# 7.6826654740513405
# 7.67964440179045
# 7.676870680739281
# 7.674324042404207
# 7.671985881735387
# 7.669839120198526
# 7.667868080182276
# 7.666058369792799
# ...
